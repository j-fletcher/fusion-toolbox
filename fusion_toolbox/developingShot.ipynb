# %%
from shot import Shot, plot_shot, plot_standard_shot
from matplotlib import pyplot as plt
# %reload_ext autoreload
# %autoreload 2

# %%
my_shot = Shot(path="shots/shot_2023010101.csv", signals=[])
# Out:
# Warning: no time column found in shot data. Creating dummy time column.

# %%
fig, axs = plt.subplots(ncols=1, nrows=2, sharex=True)
plt.sca(axs[0])
axs[0].set_ylim([0,2000])
plot_shot(my_shot, "Plasma_Current (A)", color="tab:red")
plt.sca(axs[1])
plot_shot(my_shot, "Plasma_Density (particlesm3)")
plt.show()
